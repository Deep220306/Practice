# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
df.describe()
# Out:
#              Price       Rating     Discount
# count  4188.000000  2312.000000  3970.000000
# mean   5016.970630     3.038293    24.516625
# std    2839.984813     1.143074    14.347164
# min     102.000000     1.000366     0.000000
# 25%    2628.250000     2.069490    12.000000
# 50%    4996.500000     3.082060    25.000000
# 75%    7418.000000     4.008620    37.000000
# max    9999.000000     4.997818    49.000000

# %%
df.isnull().any()
# Out:
# Category    True
# Price       True
# Rating      True
# Stock       True
# Discount    True
# dtype: bool

# %%
df['new_price']= df['Price'].fillna(df['Price'].mean())
df
# Out:
#      Category   Price    Rating         Stock  Discount   new_price
# 0         NaN  5548.0  1.870322           NaN       0.0  5548.00000
# 1         NaN  3045.0  4.757798           NaN      38.0  3045.00000
# 2         NaN  4004.0       NaN      In Stock       0.0  4004.00000
# 3         NaN  4808.0  1.492085           NaN      33.0  4808.00000
# 4         NaN  1817.0       NaN  Out of Stock      23.0  1817.00000
# ...       ...     ...       ...           ...       ...         ...
# 4357      NaN  4436.0  4.728335           NaN      49.0  4436.00000
# 4358        B  6236.0       NaN  Out of Stock       4.0  6236.00000
# 4359      NaN  3283.0       NaN  Out of Stock       9.0  3283.00000
# 4360        D  2999.0  4.425995           NaN      40.0  2999.00000
# 4361      NaN     NaN  2.184471           NaN       0.0  5016.97063
#
# [4362 rows x 6 columns]

# %%
grouped_mean_category = df.groupby('Category')['Price'].mean()
print(grouped_mean_category)
# Out:
# Category
# A    4782.910026
# B    5410.330623
# C    5086.802500
# D    5032.468672
# Name: Price, dtype: float64

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
df = pd.read_html(url)
df
# Out:
# [                                            Bank Name                City  \
#  0             Community Bank and Trust - West Georgia            LaGrange
#  1                   Metropolitan Capital Bank & Trust             Chicago
#  2                        The Santa Anna National Bank          Santa Anna
#  3                                Pulaski Savings Bank             Chicago
#  4                  The First National Bank of Lindsay             Lindsay
#  5               Republic First Bank dba Republic Bank        Philadelphia
#  6                                       Citizens Bank            Sac City
#  7                            Heartland Tri-State Bank             Elkhart
#  8                                 First Republic Bank       San Francisco
#  9                                      Signature Bank            New York
#  10                                Silicon Valley Bank         Santa Clara
# ...

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0             Community Bank and Trust - West Georgia            LaGrange
# 1                   Metropolitan Capital Bank & Trust             Chicago
# 2                        The Santa Anna National Bank          Santa Anna
# 3                                Pulaski Savings Bank             Chicago
# 4                  The First National Bank of Lindsay             Lindsay
# 5               Republic First Bank dba Republic Bank        Philadelphia
# 6                                       Citizens Bank            Sac City
# 7                            Heartland Tri-State Bank             Elkhart
# 8                                 First Republic Bank       San Francisco
# 9                                      Signature Bank            New York
# 10                                Silicon Valley Bank         Santa Clara
# 11                                  Almena State Bank              Almena
# ...

# %%
df = pd.read_excel("data.xlsx")
df
# Out:
#     name  age
# 0   deep   90
# 1  shubo   89

# %%
df.to_pickle("data.pkl")
df
# Out:
#     name  age
# 0   deep   90
# 1  shubo   89

# %%
pd.read_pickle("data.pkl")
# Out:
#     name  age
# 0   deep   90
# 1  shubo   89
